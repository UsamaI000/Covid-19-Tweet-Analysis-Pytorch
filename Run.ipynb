# %%
# !cp -r "./drive/My Drive/Covid/" "./"

# %%
! cd './Covid/' && python train.py
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# cuda
# cuda
#
# Training Started
#
# Epoch: 1/300...
# 	Train Loss: 0.034704, Train accuracy: 48.833%
# 	Train F1 Score: 0.488638
# 	Validation Loss: 0.030409, Validation accuracy: 67.053%
# 	Valid F1 Score: 0.672996
# Validation loss decreased (inf --> 0.032713). Saving model ...
#
# Epoch: 2/300...
# 	Train Loss: 0.028716, Train accuracy: 64.224%
# 	Train F1 Score: 0.642644
# 	Validation Loss: 0.030968, Validation accuracy: 72.446%
# 	Valid F1 Score: 0.727126
# Validation loss decreased (0.032713 --> 0.026980). Saving model ...
#
# Epoch: 3/300...
# 	Train Loss: 0.028763, Train accuracy: 69.819%
# 	Train F1 Score: 0.698638
# ...

# %%
# !cp -r "./Covid" "./drive/My Drive"
# !cp -r "./results" "./drive/My Drive"
