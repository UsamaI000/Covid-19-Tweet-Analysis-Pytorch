# %%
# !cp -r "./drive/My Drive/Covid-1.6/" "./"

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Training Samplestotal 99163, 0: 22186, 1: 9377, 2: 21104, 3: 33407, 4: 13089

# For weighted CE
weight = [0.22373, 0.09456, 0.21282, 0.33688, 0.13199]

# For Focal Loss
alpha = np.array([[0.767],[0.9055],[0.7872],[0.6632],[0.8681]])

# %%
! cd './Covid-1.6/' && python train.py
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Started training using cuda
#
# Training Started
#
# Epoch: 1/500...
# 	Train Loss: 1.569168, Train accuracy: 25.658%
# 	Train F1 Score: 0.256647
# 	Validation Loss: 1.539739, Validation accuracy: 33.097%
# 	Valid F1 Score: 0.331274
# Validation loss decreased (inf --> 1.516102). Saving model ...
#
# Epoch: 2/500...
# 	Train Loss: 1.426322, Train accuracy: 33.141%
# 	Train F1 Score: 0.331504
# 	Validation Loss: 1.376767, Validation accuracy: 50.389%
# 	Valid F1 Score: 0.504360
# Validation loss decreased (1.516102 --> 1.347689). Saving model ...
#
# Epoch: 3/500...
# 	Train Loss: 1.148271, Train accuracy: 41.343%
# 	Train F1 Score: 0.413543
# ...

# %%
# !cp -r "./Covid-1.6" "./drive/My Drive"
#!cp -r "./results" "./drive/My Drive"
